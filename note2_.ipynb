# %% [markdown]
# ```raw
# myproject/
# │
# ├── app.py
# ├── requirements.txt
# └── Dockerfile

# %% [markdown]
# ___

# %% [markdown]
# `app.py`
# ```python
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def home():
#     return "Docker is working!"
#
# app.run(host="0.0.0.0", port=5000)

# %% [markdown]
# ___

# %% [markdown]
# `requirements.txt`
#
# flask

# %% [markdown]
# ___
# `Dockerfile`
#
# ```Dockerfile
# FROM python:3.11
#
# WORKDIR /app
#
# COPY . .
#
# RUN pip install -r requirements.txt
#
# CMD ["python", "app.py"]
# ```

# %% [markdown]
# ___

# %% [markdown]
# ### Build Docker image

# %% [markdown]
# ```bash
# docker build -t myflaskapp .
# ```

# %% [markdown]
# - `docker build` (Tells Docker to build an image.)
# - `-t myflaskapp` ( Assigns a name (tag) to image.)
# - `.` (Use current directory as build context)

# %% [markdown]
# ___

# %% [markdown]
# ### run container

# %% [markdown]
# `docker run -p 5000:5000 myflaskapp`

# %% [markdown]
# - `docker run `- starts container from image
# - `-p 5000:5000` Port mapping- "LocalMachinePort : ContainerPort"

# %% [markdown]
# ____
